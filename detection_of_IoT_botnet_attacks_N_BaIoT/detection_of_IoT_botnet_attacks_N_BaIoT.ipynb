# %% [markdown]
# # Notebook de prueba
# Este es un bloque inicial para que Colab abra el archivo sin errores.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({"col1": np.arange(5), "col2": list('abcde')})
print('Notebook cargado correctamente ✅')
df
